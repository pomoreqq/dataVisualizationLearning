# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set_theme()

# %%
dfCars = pd.read_csv('bar_chart_data.csv')
dfCars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize=(9,6))
plt.bar(x = dfCars['Brand'],
        height= dfCars['Cars Listings'],
        color= 'red'
)

plt.xticks(rotation = 45, fontsize =13)
plt.yticks(fontsize = 13)
plt.title('Cars List by brand', fontsize = 16, fontweight = 'bold')
plt.ylabel('Number of listing', fontsize = 13)
plt.savefig('carsBarChart.png')
plt.show()

# %%
dfHomework = pd.read_csv('bar_chart_homework_data.csv')
dfHomework
# Out:
#           Cities  Frequency
# 0       New York      12327
# 1             LA      17129
# 2  San Francisco      19923
# 3          Total      49379

# %%
plt.bar(x = dfHomework['Cities'],
        height=dfHomework['Frequency'])

plt.ylabel('Frequency')
plt.title('Name of city/total')

plt.show()
